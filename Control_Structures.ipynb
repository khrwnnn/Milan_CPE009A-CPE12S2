# %% [markdown]
# <a href="https://colab.research.google.com/github/khrwnnn/Milan_CPE009A-CPE12S2/blob/main/Control_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If statement

# %%
a = 12
b = 100
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# elif statement

# %%
a = 12
b = 12
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# else statement

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand if statement

# %%
a = 12
b = 100
if b > a: print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# Short Hand if.else statement

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# And-both conditions are true

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# Or-at least one of the condition is true

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# Nested if

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  if x > 30:
    print("and also above 30!")
  else:
    print("below 30")
else:
  print("below 20")

#plus 5
# Out:
# Above ten,
# and also above 20!
# and also above 30!

# %% [markdown]
# Suplementary
#
# Example 2

# %%
a = 0
b = 0

if a > 0:
  print("The number is POSITIVE")
elif a == 0:
  print("The number is ZERO")
else:
  print("The number is NEGATIVE")

#Plus 2 pts
# Out:
# The number is ZERO

# %%
a = 2
b = 0

if a > 0:
  print("The number is POSITIVE")
elif a == 0:
  print("The number is ZERO")
else:
  print("The number is NEGATIVE")
# Out:
# The number is POSITIVE
