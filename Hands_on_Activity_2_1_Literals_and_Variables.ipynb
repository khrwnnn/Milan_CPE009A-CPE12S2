# %% [markdown]
# <a href="https://colab.research.google.com/github/khrwnnn/Milan_CPE009A-CPE12S2/blob/main/Hands_on_Activity_2_1_Literals_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4>
# Hands-on Activity 2.1 Literals and Variables
# </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed:** 1/15/26|
# | **Section**: CPE12S2 | **Date Submitted:** 1/15/26|
# | **Student Name**: Kherwin Emmanuel D. Milan | **Instructor's Name:** Sayo, Maria Rizette
# |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
#     PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
#     PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#     MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
#     MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#     FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
#     FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#     HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
#     Major exams are inputted out of 100%.
#     Show the codes that successfully run the program.
#     Provide comments or documentation strings for your program.

# %%
# Place all the output of the procedures here

# %% [markdown]
# **Supplementary Activity**:
#
# 1.    Test 3 students from the program you created.
# 2.   The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
# 3. Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**: In this activity i learned and implement literals and variables in a python program by successfully computed the Prelim, Midterm, and Final grades.

# %%
#Prelim
StudentName = input("Enter Student Name: ")
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

#Midterm
StudentName = input("Enter Student Name: ")
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*0.5 + MQUIZ*0.3 + MAS*0.2
print("Midterm CS is: ","%.2f" % MCS)
MEX = float(input("Enter Midterm Exam grade: "))
MG = (1/3*PG) + (2/3*((MEX*0.5)+(MCS*0.5)))
print("Midterm Grade is: ", "%.2f" % MG)

#Final
StudentName = input("Enter Student Name: ")
FHOA = float(input("Enter Final Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*0.5 + FQUIZ*0.3 + FAS*0.2
print("Final CS is:", "%.2f" % FCS)
FEX = float(input("Enter Final Exam grade: "))
FG = (1/3*MG) + (2/3*((FEX*0.5)+(FCS*0.5)))
print("Final Grade is:", "%.2f" % FG)

if FG >= 97:
    NG = 1.0
elif FG >= 94:
    NG = 1.25
elif FG >= 91:
    NG = 1.5
elif FG >= 88:
    NG = 1.75
elif FG >= 85:
    NG = 2.0
elif FG >= 82:
    NG = 2.25
elif FG >= 79:
    NG = 2.5
elif FG >= 76:
    NG = 2.75
elif FG >= 75:
    NG = 3.0
else:
    NG = 5.0

print("Numerical Grade is:", NG)
# Out:
# Enter Student Name: Jack
# Enter Hands-on Activity grade: 75
# Enter Prelim Quiz grade: 75
# Enter Prelim Assignment grade: 75
# Prelim CS is:  75.0
# Enter Prelim Exam grade: 75
# Prelim Grade is:  75.00
# Enter Student Name: Jose
# Enter Hands-on Activity grade: 95
# Enter Midterm Quiz grade: 85
# Enter Midterm Assignment grade: 75
# Midterm CS is:  88.00
# Enter Midterm Exam grade: 75
# Midterm Grade is:  79.33
# Enter Student Name: Diaz
# Enter Final Hands-on Activity grade: 75
# Enter Final Quiz grade: 86
# Enter Final Assignment grade: 89
# Final CS is: 81.10
# Enter Final Exam grade: 75
# Final Grade is: 78.48
# Numerical Grade is: 2.75
